# %% [markdown]
# <a href="https://colab.research.google.com/github/dayeong918/pdm011/blob/main/py-graphics/matplotlib_4_challenges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge
# ## Python module 2. **matplotlib**
# ### Python graphics using matplotlib
# - Visualization
# - Front-end deployment to WEB or Mobile

# %% [markdown]
# ### 무작위수 분포 그려보기

# %% [markdown]
# ### [도전1.] 균일분포와 정규분포를 비교하는 그림을 그리시오.
# - subplot 이용
# - style(제목, x-축 레이블, y-축 레이블, ...)
#
# > [hint] 검색: "How to add title to subplots in Matplotlib?"

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.rand(1000))
# Out:
# (array([115., 103.,  90., 103., 103.,  91., 107.,  82., 105., 101.]),
#  array([0.00123761, 0.10109761, 0.20095762, 0.30081762, 0.40067762,
#         0.50053762, 0.60039762, 0.70025762, 0.80011763, 0.89997763,
#         0.99983763]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.random.randn(1000))
# Out:
# (array([ 13.,  51., 116., 228., 215., 211., 109.,  46.,   9.,   2.]),
#  array([-2.77795921, -2.14728324, -1.51660728, -0.88593131, -0.25525535,
#          0.37542061,  1.00609658,  1.63677254,  2.2674485 ,  2.89812447,
#          3.52880043]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(8,5))
plt.subplot(121).set_title("Uniform distribution")  
plt.xlabel('x') 
plt.ylabel('y') 
plt.hist(np.random.rand(1000))

plt.subplot(122).set_title("Normal distribution") 
plt.xlabel('x') 

plt.hist(np.random.randn(1000))

plt.suptitle("Uniform distribution & Normal distribution", fontweight="bold") # 전체 제목 "Uniform distribution & Normal distribution", 글자 굵게
plt.show()

# %% [markdown]
# ### subplot(121), subplot(122)

# %% [markdown]
# ### [도전 2.] 0~9 사이의 무작위 정수 1000개를 만들어서 각 수의 빈도에 대한 히스토그램, 막대그래프, 꺽은선 그래프를 그리고 비교하시오.
# - subplot 이용
# - style(제목, x-축 레이블, y-축 레이블, ...)

# %%
n1000 = np.random.randint(0, 10, 1000)

# %%
value, count= np.unique(n1000, return_counts=True)
# count

# %%
plt.hist(n1000)
plt.show()

# %%
plt.bar(value,count) #,color="bgrcmyk")  # 'bgrcmykw
plt.show()

# %%
plt.plot(value,count,marker='o')
plt.show()

# %%
plt.figure(figsize=(12,5))

plt.subplot(131).set_title("Histogram") 
plt.xlabel('number')
plt.ylabel('count') 
plt.hist(n1000)

plt.subplot(132).set_title("Bar graph") 
plt.xlabel('number')
plt.bar(value,count,color="bgrcm")

plt.subplot(133).set_title("Line graph") 
plt.xlabel('number') 

plt.plot(value,count,'b-',marker='o',ms=8,markerfacecolor='red', markeredgecolor='k')
plt.suptitle("Histogram & Bar & Line", fontweight="bold") 

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# > [Python 그래픽스](https://datascienceschool.net/01%20python/05.01%20%EC%8B%9C%EA%B0%81%ED%99%94%20%ED%8C%A8%ED%82%A4%EC%A7%80%20%EB%A7%B7%ED%94%8C%EB%A1%AF%EB%A6%AC%EB%B8%8C%20%EC%86%8C%EA%B0%9C.html)
